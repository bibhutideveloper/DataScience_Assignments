# %%
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.cluster import KMeans

from scipy.cluster.hierarchy import dendrogram, linkage

# %%
data=pd.read_csv("stock_data.csv")

# %%
data
# Out:
#             Date   Open   High    Low  Close    Volume  Name
# 0     01-03-2006  39.69  41.22  53.22  40.91  24232729  AABA
# 1     01-04-2006  41.22  41.90  53.90  40.97  20553479  AABA
# 2     01-05-2006  40.93  41.73  53.73  41.53  12829610  AABA
# 3     01-06-2006  42.88  43.57  55.57  43.21  29422828  AABA
# 4     01-09-2006  43.10  43.66  55.66  43.42  16268338  AABA
# ...          ...    ...    ...    ...    ...       ...   ...
# 3014  12/22/2017  71.42  71.87  71.22  71.58  10979165  AABA
# 3015  12/26/2017  70.94  71.39  69.63  69.86   8542802  AABA
# 3016  12/27/2017  69.77  70.49  69.69  70.06   6345124  AABA
# 3017  12/28/2017  70.12  70.32  69.51  69.82   7556877  AABA
# 3018  12/29/2017  69.79  70.13  69.43  69.85   6613070  AABA
#
# [3019 rows x 7 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
del data["Date"]

# %%
del data["Name"]

# %%
data
# Out:
#        Open   High    Low  Close    Volume
# 0     39.69  41.22  53.22  40.91  24232729
# 1     41.22  41.90  53.90  40.97  20553479
# 2     40.93  41.73  53.73  41.53  12829610
# 3     42.88  43.57  55.57  43.21  29422828
# 4     43.10  43.66  55.66  43.42  16268338
# ...     ...    ...    ...    ...       ...
# 3014  71.42  71.87  71.22  71.58  10979165
# 3015  70.94  71.39  69.63  69.86   8542802
# 3016  69.77  70.49  69.69  70.06   6345124
# 3017  70.12  70.32  69.51  69.82   7556877
# 3018  69.79  70.13  69.43  69.85   6613070
#
# [3019 rows x 5 columns]

# %%
plt.scatter(data.Open,data.Close)
plt.show()

# %%
a=KMeans(n_clusters=10)

# %%
a.fit(data)
# Out:
# KMeans(n_clusters=10)

# %%
plt.scatter(data.Open,data.Close)
plt.plot()
# Out:
# []

# %%
plt.scatter(data.Open,data.Close,c = a.labels_)
plt.plot()
# Out:
# []

# %%
# Another method

# %%
data= [[55,78,56,6,56],[8,32,67,6,32],[65,76,45,4,32],[43,12,4,65,65],[6,22,6,56,43]]

# %%
points = ["a","b","c","d","e"]

# %%
df = pd.DataFrame(data,columns=["a","b","c","d","e"], index=points)
df
# Out:
#     a   b   c   d   e
# a  55  78  56   6  56
# b   8  32  67   6  32
# c  65  76  45   4  32
# d  43  12   4  65  65
# e   6  22   6  56  43

# %%
linkage_data = linkage(df, method='ward', metric='euclidean')
dendrogram(linkage_data)

plt.show()

# %%
linkage_data = linkage(df, method='complete', metric='euclidean')
dendrogram(linkage_data)

plt.show()

# %%
linkage_data = linkage(df, method='single', metric='euclidean')
dendrogram(linkage_data)

plt.show()

# %%
linkage_data = linkage(df, method='average', metric='euclidean')
dendrogram(linkage_data)

plt.show()

# %%
# Another method

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv("stock_data.csv")

# %%
del df1["Name"]

# %%
from sklearn.preprocessing import normalize
data_scaled = normalize(df1)
data_scaled = pd.DataFrame(data_scaled, columns=df1.columns)
data_scaled.head()
# Out:
#        Open      High       Low     Close  Volume
# 0  0.000002  0.000002  0.000002  0.000002     1.0
# 1  0.000002  0.000002  0.000003  0.000002     1.0
# 2  0.000003  0.000003  0.000004  0.000003     1.0
# 3  0.000001  0.000001  0.000002  0.000001     1.0
# 4  0.000003  0.000003  0.000003  0.000003     1.0

# %%
df1
# Out:
#             Date   Open   High    Low  Close    Volume
# 0     01-03-2006  39.69  41.22  53.22  40.91  24232729
# 1     01-04-2006  41.22  41.90  53.90  40.97  20553479
# 2     01-05-2006  40.93  41.73  53.73  41.53  12829610
# 3     01-06-2006  42.88  43.57  55.57  43.21  29422828
# 4     01-09-2006  43.10  43.66  55.66  43.42  16268338
# ...          ...    ...    ...    ...    ...       ...
# 3014  12/22/2017  71.42  71.87  71.22  71.58  10979165
# 3015  12/26/2017  70.94  71.39  69.63  69.86   8542802
# 3016  12/27/2017  69.77  70.49  69.69  70.06   6345124
# 3017  12/28/2017  70.12  70.32  69.51  69.82   7556877
# 3018  12/29/2017  69.79  70.13  69.43  69.85   6613070
#
# [3019 rows x 6 columns]

# %%
del df1["Date"]

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10, 7))  
plt.title("HCA Dendrograms")  
dend = shc.dendrogram(shc.linkage(data_scaled, method='ward'))

# %%
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(data_scaled, method='ward'))
plt.axhline(y=6, color='r', linestyle='--')

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')  
cluster.fit_predict(data_scaled)
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
plt.figure(figsize=(10, 7))  
plt.scatter(data_scaled['Open'], data_scaled['Close'], c=cluster.labels_)
